  year = date.year
  month = date.month
  day = date.day
  my_dict['date'] = pd.to_datetime(i[1])
  my_dict['temp'] = i[0]
  my_dict['year'] = f'{year}'
  my_list.append(my_dict)

# %%
min_temps = pd.DataFrame(my_list)

# %%
min_temps = min_temps.set_index('date')
max_temps = max_temps.set_index('date')

# %%
min_temps
# Out:
#            temp  year
# date
# 1965-01-01   31  1965
# 1960-01-02   29  1960
# 1950-01-03   31  1950
# 1949-01-04   29  1949
# 1949-01-05   26  1949
# ...         ...   ...
# 1962-12-27   33  1962
# 1966-12-28   32  1966
# 1988-12-29   33  1988
# 1990-12-30   33  1990
# 1978-12-31   29  1978
#
# [366 rows x 2 columns]

# %%
min_temps['1950-01-01':'1960-01-01']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   """Entry point for launching an IPython kernel.
#            temp  year
# date
# 1950-01-03   31  1950
# 1950-01-06   29  1950
# 1955-01-08   30  1955
# 1957-01-09   33  1957
# 1954-01-25   31  1954
# ...         ...   ...
# 1952-11-27   37  1952
# 1952-11-28   32  1952
# 1954-11-29   36  1954
# 1954-11-30   31  1954
# 1954-12-26   32  1954
#
# [146 rows x 2 columns]

# %%
import requests

class Weather_Api:

  """
  A class to make weather requests to the API and return 
  a cleaned, wide-form dataframe.

  Attributes:
    token: the token to access the API
    _response: internally stores the response of data requests
    _wide_df: internally stores the wide dataframe

  Methods: 
    __init__: constructor
    _make_request: private method to request data from the API
    data_request: public method to request data from the API
    format_data: public method to clean and convert data to wide_form dataframe
  """

  def __init__(self, token='ClrbcNSEeBKQrhSQeiWqRBHkpbKGiZAI'):
    self.token = token
    self._response = None
    self._wide_df = None
  
  def make_request(self, endpoint, payload = None):
    """
    Private skeleton method to request data from the weather API, 
    passing the endpoint and payload.

    Parameters:
    - endpoint: the API provides several endpoints
    - payload: a dictionary of items specifying the request

    Returns:
    - A response object
    """
    return requests.get(
        f'https://www.ncei.noaa.gov/cdo-web/api/v2/{endpoint}',
        headers={
            'token': self.token
        },
        params=payload
    )
      
  def data_request(self,
      datasetid = 'GHCND', 
      datatypeid = ['TMAX','TMIN','TAVG'], 
      stationid = 'GHCND:USW00023234', # San Francisco Airport Daily Temperature Data
      startdate = '2022-06-26',
      enddate = '2022-07-26',
      limit = 600 # maximum allowed
  ):
    """
    Make a request to the weather API with endpoint 'data',
    specifying various parameters.

    Parameters:
    - datasetid: the id of the dataset
    - datatypeid: the ids of the datatype
    - stationid: the id of the station
    - startdate: the start date
    - enddate: the end date
    - limit: the maximum number of datapoints downloaded

    Returns:
    - A response object
    """

    self._response =  self.make_request(
      endpoint = 'data', 
      payload={
          'datasetid': datasetid, 
          'datatypeid': datatypeid,
          'stationid': stationid,
          'startdate': startdate,
          'enddate': enddate,
          'limit': limit
          }
      )
    if self._response.ok:
      self._response = self._response.json()
      print('Request successful')
      print('Here\'s the metadata:')
      print(self._response['metadata'])
    else:
      print('Request unsuccessful')
    return self._response
    
    
  def format_data(self,response=None,Tcols = ['TMAX','TMIN','TAVG']):
    """
    Takes a response object and turn it into a wide-form dataframe.
    The temperature-columns are divided by 10.
    Irrelevant columns are dropped.
    The index is converted to DateTime.

    Parameters:
    - response: the response object (if not using the internal one)
    - Tcols: the temperature columns of the query - to be divided by 10

    Returns:
    - A wide-form dataframe
    """
    if (response != None):
      self._response = response
    if (self._response == None):
      raise NameError('No valid response object')     
    self._wide_df = pd.DataFrame(self._response['results'])\
              .drop(columns=['station','attributes'])\
              .assign(value = lambda which_col: 
                          np.where(which_col.datatype.apply(lambda row: row in Tcols),
                                  which_col.value/10,
                                  which_col.value) # the second lambda is necessary because the operation is vectorized under the hood
              ).pivot(
                  index = 'date',
                  columns = 'datatype',
                  values = 'value'
              )
    self._wide_df.index = pd.to_datetime(self._wide_df.index)
    return self._wide_df

# %%
instance = Weather_Api()
instance.data_request(startdate = '2021-07-25', enddate = '2022-07-24', datatypeid = ['TMAX']);
# Out:
# Request successful
# Here's the metadata:
# {'resultset': {'offset': 1, 'count': 365, 'limit': 600}}

# %%
import numpy as np
last_year_max = instance.format_data()

# %%
instance.data_request(startdate = '2021-07-25', enddate = '2022-07-24', datatypeid = ['TMIN']);
# Out:
# Request successful
# Here's the metadata:
# {'resultset': {'offset': 1, 'count': 365, 'limit': 600}}

# %%
last_year_min = instance.format_data()

# %%
last_year_min
# Out:
# datatype    TMIN
# date
# 2021-06-25  14.4
# 2021-06-26  15.0
# 2021-06-27  15.6
# 2021-06-28  15.0
# 2021-06-29  15.0
# ...          ...
# 2022-06-20  11.7
# 2022-06-21  16.1
# 2022-06-22  15.0
# 2022-06-23  13.3
# 2022-06-24  12.2
#
# [365 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

last_year_min.plot(
    kind = 'line',
    ax = ax
)
last_year_max.plot(
    kind = 'line',
    ax = ax
)
plt.show()

# %%
last_year_min
# Out:
# datatype    TMIN
# date
# 2021-06-25  14.4
# 2021-06-26  15.0
# 2021-06-27  15.6
# 2021-06-28  15.0
# 2021-06-29  15.0
# ...          ...
# 2022-06-20  11.7
# 2022-06-21  16.1
# 2022-06-22  15.0
# 2022-06-23  13.3
# 2022-06-24  12.2
#
# [365 rows x 1 columns]

# %% [markdown]
# Joining on the index is as easy as:

# %%
last_year = last_year_min.join(last_year_max)

# %%
last_year
# Out:
# datatype    TMIN  TMAX
# date
# 2021-07-25  13.3  21.7
# 2021-07-26  13.9  23.9
# 2021-07-27  14.4  23.9
# 2021-07-28  13.3  23.3
# 2021-07-29  13.9  22.2
# ...          ...   ...
# 2022-07-20  12.2  19.4
# 2022-07-21  11.7  18.3
# 2022-07-22  12.8  21.1
# 2022-07-23  12.2  20.0
# 2022-07-24  11.7  21.7
#
# [365 rows x 2 columns]

# %%
min_temps = min_temps.assign(
    to_join = lambda row: row.index.strftime('%m-%d')
)

# %%
max_temps['to_join'] = min_temps.index.strftime('%m-%d')

# %%
last_year['to_join'] = last_year.index.strftime('%m-%d')

# %%
last_year
# Out:
# datatype    TMIN  TMAX to_join
# date
# 2021-06-25  14.4  21.7   06-25
# 2021-06-26  15.0  21.1   06-26
# 2021-06-27  15.6  21.7   06-27
# 2021-06-28  15.0  20.6   06-28
# 2021-06-29  15.0  21.7   06-29
# ...          ...   ...     ...
# 2022-06-20  11.7  26.7   06-20
# 2022-06-21  16.1  36.7   06-21
# 2022-06-22  15.0  28.3   06-22
# 2022-06-23  13.3  23.3   06-23
# 2022-06-24  12.2  23.9   06-24
#
# [365 rows x 3 columns]

# %%
min_temps.min_year.astype(int)
# Out:
# date
# 1965-01-01    1965
# 1960-01-02    1960
# 1950-01-03    1950
# 1949-01-04    1949
# 1949-01-05    1949
#               ...
# 1962-12-27    1962
# 1966-12-28    1966
# 1988-12-29    1988
# 1990-12-30    1990
# 1978-12-31    1978
# Name: min_year, Length: 366, dtype: int64

# %%
max_temps = max_temps.rename(
    columns = {
        'temp': 'record_max',
        'year': 'max_year'
              }
            ).assign(
                record_max = lambda which: which.record_max.astype(int),
                max_year = lambda which: which.max_year.astype(int),
            )
min_temps = min_temps.rename(
    columns = {
        'temp': 'record_min',
        'year': 'min_year'
              }
            ).assign(
                record_min = lambda which: which.record_min.astype(int),
                min_year = lambda which: which.min_year.astype(int),
            )
            
last_year = last_year.rename(
    columns = {
        'TMIN': 'last_year_low',
        'TMAX': 'last_year_high'
    }
)

altogether = last_year.merge(right=max_temps,how='left', on='to_join')\
         .merge(right=min_temps,how='left', on='to_join')\
         .rename(columns={'to_join': 'date'})\
         .set_index('date')\
         .assign(
             last_year_low = lambda which: round(which.last_year_low*9/5+32).astype(int),
             last_year_high = lambda which: round(which.last_year_high*9/5+32).astype(int)
         )

# %%
altogether
# Out:
#        last_year_low  last_year_high  record_max  max_year  record_min  \
# date
# 07-25             56              71          91      1973          49
# 07-26             57              75          94      1963          49
# 07-27             58              75          86      1967          48
# 07-28             56              74          88      1954          48
# 07-29             57              72          91      1977          44
# ...              ...             ...         ...       ...         ...
# 07-20             54              67          93      1996          49
# 07-21             53              65          83      2006          49
# 07-22             55              70          97      2006          49
# 07-23             54              68          89      2005          50
# 07-24             53              71          90      1974          50
#
#        min_year
# date
# 07-25      1953
# 07-26      1951
# 07-27      1951
# 07-28      1953
# ...

# %%
altogether.drop(columns = ['min_year','max_year']).plot(
    kind = 'line',
    figsize = (8,8),
    ylabel = 'temp_F'
)

# %%
altogether[['min_year','max_year']].plot(
    kind = 'line',
    figsize = (8,8),
)

# %%
altogether[['min_year','max_year']].plot(
    kind = 'box',
    figsize = (8,8),
)

# %%
import seaborn as sns
sns.violinplot(data=altogether[['min_year','max_year']])

# %% [markdown]
# Note the seaborn scale seems a bit off.

# %% [markdown]
# ## Finishing Iris

# %%
import numpy as np

class Perceptron:
  def __init__(self, lrate = 0.1, niter = 10):
    self.lrate = lrate
    self.niter = niter

  def fit(self,X,y):
    self.a_1 = 0.0
    self.a_2 = 0.0
    self.b = 0.0    
    for i in range(self.niter):
      for x_i, target in zip(X,y):
        update = (target - self.predict(x_i))
        if update == 1.0:
          denom = 1 + x_i[0]**2 + x_i[1]**2
          self.a_1 += x_i[0]*self.lrate/denom
          self.a_2 += x_i[1]*self.lrate/denom
          self.b += self.lrate/denom
        elif update == -1.0:
          denom = 1 + x_i[0]**2 + x_i[1]**2
          self.a_1 -= x_i[0]*self.lrate/denom
          self.a_2 -= x_i[1]*self.lrate/denom
          self.b -= self.lrate/denom          
        elif update == 0.0:
          pass
        else: 
          raise ValueError('target - predict should be -1,0,1')
    return None
  
  def predict(self,x_i):
    return np.where(self.net_input(x_i) >= 0.5, 1, 0)

  def net_input(self,x_i):
    return self.a_1*x_i[0] + self.a_2*x_i[1] + self.b

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
y = pd.Series(y)
X = pd.DataFrame(X,columns=['Sepal length','Sepal width','Petal Length','Petal Width'])

# %%
y.unique()
# Out:
# array([0, 1, 2])

# %%
X_mod = X.loc[y!=2,['Sepal length','Sepal width']]

# %%
X_mod
# Out:
#       0    1
# 0   5.1  3.5
# 1   4.9  3.0
# 2   4.7  3.2
# 3   4.6  3.1
# 4   5.0  3.6
# ..  ...  ...
# 95  5.7  3.0
# 96  5.7  2.9
# 97  6.2  2.9
# 98  5.1  2.5
# 99  5.7  2.8
#
# [100 rows x 2 columns]

# %%
y_mod = y[y!=2]

# %%
perc = Perceptron(lrate = 0.003, niter = 1000)
perc.fit(X_mod.values,y_mod.values)

# %% [markdown]
# let's visualize this prediction

# %%
X_mod
# Out:
#       0    1
# 0   5.1  3.5
# 1   4.9  3.0
# 2   4.7  3.2
# 3   4.6  3.1
# 4   5.0  3.6
# ..  ...  ...
# 95  5.7  3.0
# 96  5.7  2.9
# 97  6.2  2.9
# 98  5.1  2.5
# 99  5.7  2.8
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,8))
X_mod.loc[y == 0,:].plot(kind='scatter',x='Sepal length', y='Sepal width', ax = ax, color='blue')
X_mod.loc[y == 1,:].plot(kind='scatter',x='Sepal length', y='Sepal width', ax = ax, color='orange')
plt.show()

# %% [markdown]
# 0.5 = a_1 x_1 + a_2 x_2 + b

# %%
perc.a_1
# Out:
# 0.10242215742807854

# %%
xx1 = np.linspace(4,7,100)
xx2 = (0.5 - perc.b - perc.a_1 * xx1)/perc.a_2

# %%
xx2
# Out:
# array([0.10406941, 0.17348888, 0.24290834, 0.31232781, 0.38174727,
#        0.45116674, 0.5205862 , 0.59000567, 0.65942513, 0.7288446 ,
#        0.79826406, 0.86768353, 0.93710299, 1.00652246, 1.07594192,
#        1.14536139, 1.21478085, 1.28420032, 1.35361978, 1.42303925,
#        1.49245871, 1.56187818, 1.63129764, 1.70071711, 1.77013657,
#        1.83955604, 1.9089755 , 1.97839497, 2.04781443, 2.1172339 ,
#        2.18665336, 2.25607283, 2.32549229, 2.39491176, 2.46433122,
#        2.53375069, 2.60317015, 2.67258962, 2.74200908, 2.81142855,
#        2.88084801, 2.95026748, 3.01968694, 3.08910641, 3.15852587,
#        3.22794534, 3.2973648 , 3.36678427, 3.43620373, 3.5056232 ,
#        3.57504266, 3.64446213, 3.71388159, 3.78330106, 3.85272052,
#        3.92213999, 3.99155945, 4.06097892, 4.13039838, 4.19981785,
#        4.26923731, 4.33865678, 4.40807624, 4.47749571, 4.54691517,
#        4.61633464, 4.6857541 , 4.75517357, 4.82459303, 4.8940125 ,
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,8))
X_mod.loc[y == 0,:].plot(kind='scatter',x='Sepal length', y='Sepal width', ax = ax, color='blue')
X_mod.loc[y == 1,:].plot(kind='scatter',x='Sepal length', y='Sepal width', ax = ax, color='orange')
ax.plot(xx1, xx2)
plt.xlim([4,7])
plt.ylim([2,4.5])
plt.show()

# %%
correct = 0
for i in range(len(y_mod)):
  print(f'we predicted {perc.predict(X_mod.loc[i,:].values)}')
  print(f'y is really {y[i]}')
  if perc.predict(X_mod.loc[i,:].values) == y_mod[i]:
    print('we predicted correctly')
    correct += 1
  else:
    print('we predicted incorrectly')
print(f'we predicted {correct} out of {len(y_mod)} correctly.')
# Out:
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# we predicted 0
# y is really 0
# we predicted correctly
# ...

# %% [markdown]
# ## Penguins

# %%
# !pip install palmerpenguins

# %%
from palmerpenguins import load_penguins
df = load_penguins()

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 8         3475.0  NaN  2007
# ...

# %% [markdown]
# Let's drop 3 and 271. The other ones we just don't have the sex.

# %%
df = df.drop(index=[3,271])

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
import seaborn as sns
g = sns.lmplot(x="flipper_length_mm",
               y="body_mass_g",
               hue="species",
               height=7,
               data=df,
               palette=['#FF8C00','#159090','#A034F0'])
g.set_xlabels('Flipper Length')
g.set_ylabels('Body Mass')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
#from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
lr_pipe = make_pipeline(
    StandardScaler(),
    #PCA(),
    LogisticRegression()
)
from sklearn.model_selection import train_test_split

train_test_split()
